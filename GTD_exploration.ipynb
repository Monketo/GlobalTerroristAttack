# %%
import pandas as pd
pd.set_option("display.max_columns",200)

# %%
data = pd.read_excel("globalterrorismdb_0617dist.xlsx")

# %%
counts = pd.DataFrame(data["gname"].value_counts())

# %%
counts[counts["gname"]<10]
# Out:
#                                                     gname
# Eastern Turkistan Islamic Movement (ETIM)               9
# Manipur Naga People's Army (MNPA)                       9
# Reform of the Armed Forces Movement                     9
# South Moluccans                                         9
# Mohajir National Movement                               9
# Luis Boitel Commandos                                   9
# Armenian Guerrillas                                     9
# Turkish Leftists                                        9
# Serbian extremists                                      9
# Kanglei Yawol Kanna Lup (KYKL)                          9
# Bhinderanwale Tiger Force of Khalistan (BTHK)           9
# Japanese Red Army (JRA)                                 9
# Communist Party of India- Marxist                       9
# Peronist Armed Forces (FAP)                             9
# Madhesi Mukti Tigers (MMT)                              9
# ...
